# %%
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime
import numpy as np
import pandas as pd
import urllib
import json

with open('api_keys.json') as f:
  api_keys = json.load(f)

api_key = api_keys['etherscan']
etherscan_stats_endpoint = 'https://api.etherscan.io/api?module=stats'

# %%
action = 'ethprice'
url = '{}&action={}&apikey={}'.format(etherscan_stats_endpoint, action, api_key)
result = urllib.request.urlopen(url)

print(result.read().decode("utf-8"))
# Out:
# {"status":"1","message":"OK","result":{"ethbtc":"0.04125","ethbtc_timestamp":"1612727629","ethusd":"1583.49","ethusd_timestamp":"1612727638"}}

# %%
action = 'nodecount'
url = '{}&action={}&apikey={}'.format(etherscan_stats_endpoint, action, api_key)
result = urllib.request.urlopen(url)

print(result.read().decode("utf-8"))
# Out:
# {"status":"1","message":"OK","result":{"UTCDate":"2021-02-06","TotalNodeCount":"8393"}}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

with open('api_keys.json') as f:
  api_keys = json.load(f)

api_key = api_keys['coinmarketcap']
coinmarketcap_stats_endpoint = 'https://api.etherscan.io/api?module=stats'



url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': api_key,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2021-02-07T22:35:16.377Z', 'error_code': 0, 'error_message': None, 'elapsed': 142, 'credit_count': 21, 'notice': None, 'total_count': 4026}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9614, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio'], 'max_supply': 21000000, 'circulating_supply': 18622487, 'total_supply': 18622487, 'platform': None, 'cmc_rank': 1, 'last_updated': '2021-02-07T22:34:02.000Z', 'quote': {'USD': {'price': 38407.05711447101, 'volume_24h': 66034879003.99488, 'percent_change_1h': 0.75392351, 'percent_change_24h': -4.40035774, 'percent_change_7d': 17.36701211, 'percent_change_30d': -3.67697289, 'market_cap': 715234921822.4939, 'last_updated': '2021-02-07T22:34:02.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'eth
# ...

# %%
for ky in data.keys():
    print(ky)
# Out:
# status
# data

# %%
for ky in data['data']:
    if ky['name'] == 'Ethereum':
        print(ky)
# Out:
# {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5831, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio'], 'max_supply': None, 'circulating_supply': 114578160.499, 'total_supply': 114578160.499, 'platform': None, 'cmc_rank': 2, 'last_updated': '2021-02-07T22:34:02.000Z', 'quote': {'USD': {'price': 1583.2339699086247, 'volume_24h': 39205136044.49619, 'percent_change_1h': 0.72193228, 'percent_change_24h': -7.14053919, 'percent_change_7d': 21.6667842, 'percent_change_30d': 33.5351086, 'market_cap': 181404035911.65933, 'last_updated': '2021-02-07T22:34:02.000Z'}}}

# %%
for ky in data['data']:
    if ky['name'] == 'Bitcoin':
        print(ky)
# Out:
# {'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9614, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio'], 'max_supply': 21000000, 'circulating_supply': 18622487, 'total_supply': 18622487, 'platform': None, 'cmc_rank': 1, 'last_updated': '2021-02-07T22:34:02.000Z', 'quote': {'USD': {'price': 38407.05711447101, 'volume_24h': 66034879003.99488, 'percent_change_1h': 0.75392351, 'percent_change_24h': -4.40035774, 'percent_change_7d': 17.36701211, 'percent_change_30d': -3.67697289, 'market_cap': 715234921822.4939, 'last_updated': '2021-02-07T22:34:02.000Z'}}}
